# %% [markdown]
# ## summary statistics (mean, median, minimum, maximum, standard deviation) for a dataset (age, income etc.)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("salary.csv")

# %%
df.head()
# Out:
#                 Name  Age  Salary
# 0      Mckenzie Roth   25  111378
# 1       Roy Hamilton   51  113406
# 2  Mackenzie Kennedy   57   73070
# 3     Maxwell McLean   38   84151
# 4         Sky Gentry   33   75313

# %%
df.describe()
# Out:
#                Age         Salary
# count  1000.000000    1000.000000
# mean     41.416000   67523.441000
# std      13.951903   31690.323817
# min      18.000000   10546.000000
# 25%      29.000000   40317.000000
# 50%      41.000000   69744.500000
# 75%      53.000000   93380.000000
# max      65.000000  119905.000000

# %%
grouped_df = df.groupby('Age')

# %%
grouped_df.describe()
# Out:
#     Salary                                                                     \
#      count          mean           std      min       25%      50%        75%
# Age
# 18    22.0  70174.772727  26998.850988  20196.0  55272.75  70642.0   88249.50
# 19    21.0  70405.238095  36276.976478  19685.0  35513.00  69216.0   99547.00
# 20    30.0  67478.533333  34057.109429  10546.0  36332.75  71537.5   98729.00
# 21    19.0  64386.052632  36867.369257  11254.0  32090.50  58881.0   96562.00
# 22    13.0  71548.153846  34954.774678  14471.0  41804.00  73314.0   91077.00
# 23    27.0  73531.814815  28278.996128  27478.0  53243.50  78886.0   90591.50
# 24    19.0  75387.684211  30353.268534  14541.0  56978.50  85388.0  101002.50
# 25    15.0  63991.466667  26206.713469  29936.0  43222.00  67149.0   78804.50
# 26    28.0  70270.857143  28209.685127  19722.0  50031.00  69239.5   95428.25
# 27    23.0  62034.608696  35822.501529  15170.0  30228.00  58621.0   97633.50
# ...

# %% [markdown]
# ## Python program to display some basic statistical details of Iris Flower

# %%
df2=pd.read_csv('IRIS.csv')

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
